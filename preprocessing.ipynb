# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
raw_df = pd.read_csv('retail_data_Source.csv')

# %%
raw_df
# Out:
#        Transaction_ID  Customer_ID               Name                 Email  \
# 0           1222404.0      54688.0         Jimmy Barr    Joshua35@gmail.com
# 1           2276788.0      76511.0        Tammy Welch     Teresa5@gmail.com
# 2           6544646.0      29062.0        Erin Rogers   Melissa54@gmail.com
# 3           3399995.0      77396.0       Andrew Brown   Jennifer5@gmail.com
# 4           2893264.0      43461.0  Matthew Wilkinson    Nicole57@gmail.com
# ...               ...          ...                ...                   ...
# 57508       8992179.0      55098.0    Patricia Harper     Jacob47@gmail.com
# 57509       4989475.0      29217.0   Jamie Livingston     Kevin85@gmail.com
# 57510       4015075.0      98322.0  Joshua Valenzuela     Jesse62@gmail.com
# 57511       4487444.0      59312.0       Tracy Holmes  Patricia72@gmail.com
# 57512       6826016.0      23859.0         Todd Kelly   Gregory19@gmail.com
#
# ...

# %%
df_clean = raw_df.dropna(subset=["Transaction_ID", "Customer_ID"]).reset_index(drop=True)

# %%
df_invalid = raw_df[raw_df[["Transaction_ID", "Customer_ID"]].isna().any(axis=1)].reset_index(drop=True)

# %%
df_clean
# Out:
#        Transaction_ID  Customer_ID               Name                 Email  \
# 0           1222404.0      54688.0         Jimmy Barr    Joshua35@gmail.com
# 1           2276788.0      76511.0        Tammy Welch     Teresa5@gmail.com
# 2           6544646.0      29062.0        Erin Rogers   Melissa54@gmail.com
# 3           3399995.0      77396.0       Andrew Brown   Jennifer5@gmail.com
# 4           2893264.0      43461.0  Matthew Wilkinson    Nicole57@gmail.com
# ...               ...          ...                ...                   ...
# 57392       8992179.0      55098.0    Patricia Harper     Jacob47@gmail.com
# 57393       4989475.0      29217.0   Jamie Livingston     Kevin85@gmail.com
# 57394       4015075.0      98322.0  Joshua Valenzuela     Jesse62@gmail.com
# 57395       4487444.0      59312.0       Tracy Holmes  Patricia72@gmail.com
# 57396       6826016.0      23859.0         Todd Kelly   Gregory19@gmail.com
#
# ...

# %%
df_clean
# Out:
#        Transaction_ID  Customer_ID               Name                 Email  \
# 0           1222404.0      54688.0         Jimmy Barr    Joshua35@gmail.com
# 1           2276788.0      76511.0        Tammy Welch     Teresa5@gmail.com
# 2           6544646.0      29062.0        Erin Rogers   Melissa54@gmail.com
# 3           3399995.0      77396.0       Andrew Brown   Jennifer5@gmail.com
# 4           2893264.0      43461.0  Matthew Wilkinson    Nicole57@gmail.com
# ...               ...          ...                ...                   ...
# 57392       8992179.0      55098.0    Patricia Harper     Jacob47@gmail.com
# 57393       4989475.0      29217.0   Jamie Livingston     Kevin85@gmail.com
# 57394       4015075.0      98322.0  Joshua Valenzuela     Jesse62@gmail.com
# 57395       4487444.0      59312.0       Tracy Holmes  Patricia72@gmail.com
# 57396       6826016.0      23859.0         Todd Kelly   Gregory19@gmail.com
#
# ...
